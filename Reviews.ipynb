# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_train = pd.read_csv('IMDB Dataset.csv')

# %%
df_train.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df_train.head()
# Out:
#                                               review  sentiment
# 0  One of the other reviewers has mentioned that ...          1
# 1  A wonderful little production. <br /><br />The...          1
# 2  I thought this was a wonderful way to spend ti...          1
# 3  Basically there's a family where a little boy ...          0
# 4  Petter Mattei's "Love in the Time of Money" is...          1

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   review     50000 non-null  object
#  1   sentiment  50000 non-null  object
# dtypes: object(2)
# memory usage: 781.4+ KB

# %% [markdown]
# # negative - 0   positive - 1

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = LabelEncoder()

# %%
df_train['sentiment'] = label.fit_transform(df_train['sentiment'])

# %%
from sklearn.pipeline import Pipeline

# %%
from sklearn.model_selection import GridSearchCV

# %%
from xgboost import XGBClassifier

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer()

# %%
model =  XGBClassifier()

# %%
X_train = df_train['review']
y_train = df_train['sentiment']

# %%
params = {
    'model__n_estimators' : [100,150,200,250,300],
    'model__max_depth' : [7]
}

# %%
pipe = Pipeline([('tfidf',tfidf),('model',model)])

# %%
final_model = GridSearchCV(pipe,param_grid=params,cv=3,verbose=2)

# %%
final_model.fit(X_train,y_train)
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [CV] END ........model__max_depth=7, model__n_estimators=100; total time= 1.3min
# [CV] END ........model__max_depth=7, model__n_estimators=100; total time= 1.2min
# [CV] END ........model__max_depth=7, model__n_estimators=100; total time= 1.1min
# [CV] END ........model__max_depth=7, model__n_estimators=150; total time= 1.6min
# [CV] END ........model__max_depth=7, model__n_estimators=150; total time= 1.5min
# [CV] END ........model__max_depth=7, model__n_estimators=150; total time= 1.5min
# [CV] END ........model__max_depth=7, model__n_estimators=200; total time= 1.9min
# [CV] END ........model__max_depth=7, model__n_estimators=200; total time= 1.9min
# [CV] END ........model__max_depth=7, model__n_estimators=200; total time= 1.9min
# [CV] END ........model__max_depth=7, model__n_estimators=250; total time= 2.2min
# [CV] END ........model__max_depth=7, model__n_estimators=250; total time= 2.2min
# [CV] END ........model__max_depth=7, model__n_estimators=250; total time= 2.2min
# [CV] END ........model__max_depth=7, model__n_estimators=300; total time= 2.5min
# [CV] END ........model__max_depth=7, model__n_estimators=300; total time= 2.5min
# [CV] END ........model__max_depth=7, model__n_estimators=300; total time= 2.5min
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                                        ('model',
#                                         XGBClassifier(base_score=None,
#                                                       booster=None,
#                                                       callbacks=None,
#                                                       colsample_bylevel=None,
#                                                       colsample_bynode=None,
#                                                       colsample_bytree=None,
#                                                       device=None,
#                                                       early_stopping_rounds=None,
#                                                       enable_categorical=False,
#                                                       eval_metric=None,
#                                                       feature_types=None,
#                                                       feature_weights=None,
#                                                       gamma=None,
#                                                       grow_policy=...
#                                                       learning_rate=None,
#                                                       max_bin=None,
#                                                       max_cat_threshold=None,
#                                                       max_cat_to_onehot=None,
#                                                       max_delta_step=None,
#                                                       max_depth=None,
#                                                       max_leaves=None,
#                                                       min_child_weight=None,
#                                                       missing=nan,
#                                                       monotone_constraints=None,
#                                                       multi_strategy=None,
#                                                       n_estimators=None,
#                                                       n_jobs=None,
#                                                       num_parallel_tree=None, ...))]),
#              param_grid={'model__max_depth': [7],
#                          'model__n_estimators': [100, 150, 200, 250, 300]},
#              verbose=2)

# %%
final_model.best_params_
# Out:
# {'model__max_depth': 7, 'model__n_estimators': 300}

# %%
import pickle

# %%
with open('model.pkl', 'wb') as file:
    pickle.dump(final_model,file)
